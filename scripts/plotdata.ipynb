# %%
import pandas as pd

# %%
#clean files befete running this code
#df = pd.read_csv("C:/Users/josei/OneDrive/Escritorio/20240523_080337/Xsens DOT_3_D422CD006786_20240523_080248.csv")
df = pd.read_csv("C:/Users/josei/OneDrive/Documentos/CIIBI proyectos/Analisys Free Squat/datatest/20240523_080337_melisa/Xsens DOT_3_D422CD006786_20240523_080248.csv")

f = 60#Hz
df['ElapsedTime'] = (df['PacketCounter']-1)*(1/f)
df.head()
# Out:
#    PacketCounter  SampleTimeFine     Euler_X    Euler_Y     Euler_Z     Acc_X  \
# 0              0       180733222  174.290482 -66.788681  118.607849  0.000000
# 1              1       180749889  174.553772 -66.657997  118.381752  9.189401
# 2              2       180766556  174.816956 -66.536285  118.186928  9.112556
# 3              3       180783223  175.046722 -66.406731  117.970016  8.943201
# 4              4       180799890  175.278336 -66.162277  117.690102  8.831895
#
#       Acc_Y     Acc_Z     Gyr_X      Gyr_Y     Gyr_Z  ElapsedTime
# 0  0.000000  0.000000  0.000000   0.000000  0.000000    -0.016667
# 1  0.025760 -3.734761  2.683886 -10.632874  4.751471     0.000000
# 2  0.050948 -3.925130  4.411194 -10.009807  4.125279     0.016667
# 3  0.562012 -3.783629  1.199706 -10.505580  4.667091     0.033333
# 4  0.392802 -4.431056 -2.133233 -17.486692  5.680167     0.050000

# %%
import plotly.express as px
px.scatter(df,x='ElapsedTime',y='Acc_Z')
